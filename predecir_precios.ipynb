# %% [markdown]
# <div align="center">
#   <a href="https://www.davivienda.com/wps/portal/personas/nuevo">
#     <img src="https://upload.wikimedia.org/wikipedia/en/thumb/b/b1/Davivienda_logo.svg/1200px-Davivienda_logo.svg.png" alt="Logo" width="300" height="100">
#   </a>
#
#   <h2 align="center">Prueba Técnica Davivienda ADNe - Especialista I</h2>
#   <h2 align="center">Notebook de Implementación Predicción de Precios</h2>
#   <h4 align="center">Luvan Tabares</h4>
#
# ***
#
#   <p align="left">
#     Se requiere desarrollar un modelo predictivo para estimar el valor total de avaluo de viviendas utilizando herramientas avanzadas de análisis de datos y machine learning. El objetivo es procesar las características de los inmuebles presentes en la base de datos para identificar patrones que permitan predecir el precio de propiedades que aún no han sido evaluadas.
#   <p align="left">
#     Este modelo será de gran utilidad en varios procesos bancarios, tales como:
#   <p align="left">
#     - Originación: Determinación del valor comercial del inmueble a financiar, crucial para la aprobación final de créditos.
#   <p align="left">
#     - Retanqueo: Actualización del valor comercial de garantías existentes, necesaria para la aprobación de nuevos cupos de crédito.
#   <p align="left">
#     - Monitoreo del Portafolio de Garantías: Valoración continua del portafolio de garantías, asegurando el cumplimiento normativo y facilitando el análisis de riesgos del colateral.
#   <p align="left">
#     - Normalización de Cartera: Evaluación de préstamos existentes y acuerdos de refinanciamiento, así como daciones en pago.
#
#   </p>
# </div>
#
# ## Tabla de contenidos
#
# 1. [Instalación de librerías y llamado de librerías](#first) <br />
# 2. [Exploración de datos](#second) <br />
# 3. [Extracción de tópicos](#third) <br />
# 4. [Análisis de sentimiento](#fourth) <br />
# 5. [Análisis de resultados](#fifth) <br />

# %% [markdown]
# ## 1. Librerias a instalar <a id="first"></a>

# %%
# !pip install -r requirements.txt

"""
pip install 
"""
# Out:
# Requirement already satisfied: asttokens==2.4.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Collecting attrs==23.2.0 (from -r requirements.txt (line 2))
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting bertopic==0.16.2 (from -r requirements.txt (line 3))
#   Using cached bertopic-0.16.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting certifi==2024.7.4 (from -r requirements.txt (line 4))
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2 (from -r requirements.txt (line 5))
#   Using cached charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: comm==0.2.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.2.2)
# Collecting contourpy==1.2.1 (from -r requirements.txt (line 7))
#   Using cached contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler==0.12.1 (from -r requirements.txt (line 8))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting Cython==0.29.37 (from -r requirements.txt (line 9))
#   Using cached Cython-0.29.37-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: debugpy==1.8.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.8.2)
# Requirement already satisfied: decorator==5.1.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: exceptiongroup==1.2.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.2.2)
# Requirement already satisfied: executing==2.0.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (2.0.1)
# Collecting fastjsonschema==2.20.0 (from -r requirements.txt (line 14))
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting filelock==3.15.4 (from -r requirements.txt (line 15))
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting fonttools==4.53.1 (from -r requirements.txt (line 16))
#   Using cached fonttools-4.53.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
# Collecting fsspec==2024.6.1 (from -r requirements.txt (line 17))
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting hdbscan==0.8.37 (from -r requirements.txt (line 18))
#   Using cached hdbscan-0.8.37-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting huggingface-hub==0.24.0 (from -r requirements.txt (line 19))
#   Using cached huggingface_hub-0.24.0-py3-none-any.whl.metadata (13 kB)
# Collecting idna==3.7 (from -r requirements.txt (line 20))
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: importlib_metadata==8.0.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (8.0.0)
# Collecting importlib_resources==6.4.0 (from -r requirements.txt (line 22))
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: ipykernel==6.29.5 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (6.29.5)
# Requirement already satisfied: ipython==8.18.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (8.18.1)
# Requirement already satisfied: jedi==0.19.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.19.1)
# Collecting Jinja2==3.1.4 (from -r requirements.txt (line 26))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib==1.4.2 (from -r requirements.txt (line 27))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting jsonschema==4.23.0 (from -r requirements.txt (line 28))
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-specifications==2023.12.1 (from -r requirements.txt (line 29))
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jupyter_client==8.6.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (8.6.2)
# Requirement already satisfied: jupyter_core==5.7.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (5.7.2)
# Collecting kiwisolver==1.4.5 (from -r requirements.txt (line 32))
#   Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Collecting llvmlite==0.43.0 (from -r requirements.txt (line 33))
#   Using cached llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting MarkupSafe==2.1.5 (from -r requirements.txt (line 34))
#   Using cached MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib==3.9.1 (from -r requirements.txt (line 35))
#   Using cached matplotlib-3.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.1.7)
# Collecting mpmath==1.3.0 (from -r requirements.txt (line 37))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting nbformat==5.10.4 (from -r requirements.txt (line 38))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (1.6.0)
# Collecting networkx==3.2.1 (from -r requirements.txt (line 40))
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting numba==0.60.0 (from -r requirements.txt (line 41))
#   Using cached numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 42))
#   Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from -r requirements.txt (line 43))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from -r requirements.txt (line 44))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from -r requirements.txt (line 45))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from -r requirements.txt (line 46))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from -r requirements.txt (line 47))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from -r requirements.txt (line 48))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from -r requirements.txt (line 49))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from -r requirements.txt (line 50))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from -r requirements.txt (line 51))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from -r requirements.txt (line 52))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.5.82 (from -r requirements.txt (line 53))
#   Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from -r requirements.txt (line 54))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: packaging==24.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 55)) (24.1)
# Collecting pandas==2.2.2 (from -r requirements.txt (line 56))
#   Using cached pandas-2.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: parso==0.8.4 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (4.9.0)
# Collecting pillow==10.4.0 (from -r requirements.txt (line 59))
#   Using cached pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: platformdirs==4.2.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 60)) (4.2.2)
# Collecting plotly==5.22.0 (from -r requirements.txt (line 61))
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: prompt_toolkit==3.0.47 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 62)) (3.0.47)
# Requirement already satisfied: psutil==6.0.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 63)) (6.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 64)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 65)) (0.2.2)
# Requirement already satisfied: Pygments==2.18.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 66)) (2.18.0)
# Collecting pynndescent==0.5.13 (from -r requirements.txt (line 67))
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting pyparsing==3.1.2 (from -r requirements.txt (line 68))
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 69)) (2.9.0.post0)
# Collecting pytz==2024.1 (from -r requirements.txt (line 70))
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting PyYAML==6.0.1 (from -r requirements.txt (line 71))
#   Using cached PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: pyzmq==26.0.3 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 72)) (26.0.3)
# Collecting referencing==0.35.1 (from -r requirements.txt (line 73))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting regex==2024.5.15 (from -r requirements.txt (line 74))
#   Using cached regex-2024.5.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests==2.32.3 (from -r requirements.txt (line 75))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting rpds-py==0.19.0 (from -r requirements.txt (line 76))
#   Using cached rpds_py-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting safetensors==0.4.3 (from -r requirements.txt (line 77))
#   Using cached safetensors-0.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting scikit-learn==1.5.1 (from -r requirements.txt (line 78))
#   Using cached scikit_learn-1.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting scipy==1.13.1 (from -r requirements.txt (line 79))
#   Using cached scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting seaborn==0.13.2 (from -r requirements.txt (line 80))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting sentence-transformers==3.0.1 (from -r requirements.txt (line 81))
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six==1.16.0 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 82)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 83)) (0.6.3)
# Collecting sympy==1.13.1 (from -r requirements.txt (line 84))
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting tenacity==8.5.0 (from -r requirements.txt (line 85))
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting threadpoolctl==3.5.0 (from -r requirements.txt (line 86))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting tokenizers==0.19.1 (from -r requirements.txt (line 87))
#   Using cached tokenizers-0.19.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting torch==2.3.1 (from -r requirements.txt (line 88))
#   Using cached torch-2.3.1-cp39-cp39-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.3.1 (from -r requirements.txt (line 89))
#   Using cached torchaudio-2.3.1-cp39-cp39-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.18.1 (from -r requirements.txt (line 90))
#   Using cached torchvision-0.18.1-cp39-cp39-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tornado==6.4.1 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 91)) (6.4.1)
# Collecting tqdm==4.66.4 (from -r requirements.txt (line 92))
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: traitlets==5.14.3 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 93)) (5.14.3)
# Collecting transformers==4.42.4 (from -r requirements.txt (line 94))
#   Using cached transformers-4.42.4-py3-none-any.whl.metadata (43 kB)
# Collecting triton==2.3.1 (from -r requirements.txt (line 95))
#   Using cached triton-2.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: typing_extensions==4.12.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 96)) (4.12.2)
# Collecting tzdata==2024.1 (from -r requirements.txt (line 97))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting umap-learn==0.5.6 (from -r requirements.txt (line 98))
#   Using cached umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting urllib3==2.2.2 (from -r requirements.txt (line 99))
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 100)) (0.2.13)
# Requirement already satisfied: zipp==3.19.2 in /home/luvanpc/anaconda3/envs/tweets/lib/python3.9/site-packages (from -r requirements.txt (line 101)) (3.19.2)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached bertopic-0.16.2-py2.py3-none-any.whl (158 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached Cython-0.29.37-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached fonttools-4.53.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached hdbscan-0.8.37-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
# Using cached huggingface_hub-0.24.0-py3-none-any.whl (419 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
# Using cached MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached matplotlib-3.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
# Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached pandas-2.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Using cached pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached regex-2024.5.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (774 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached rpds_py-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (356 kB)
# Using cached safetensors-0.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Using cached scikit_learn-1.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
# Using cached scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tokenizers-0.19.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached torch-2.3.1-cp39-cp39-manylinux1_x86_64.whl (779.1 MB)
# Using cached torchaudio-2.3.1-cp39-cp39-manylinux1_x86_64.whl (3.4 MB)
# Using cached torchvision-0.18.1-cp39-cp39-manylinux1_x86_64.whl (7.0 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached transformers-4.42.4-py3-none-any.whl (9.3 MB)
# Using cached triton-2.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: pytz, mpmath, fastjsonschema, urllib3, tzdata, tqdm, threadpoolctl, tenacity, sympy, safetensors, rpds-py, regex, PyYAML, pyparsing, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, llvmlite, kiwisolver, joblib, importlib_resources, idna, fsspec, fonttools, filelock, Cython, cycler, charset-normalizer, certifi, attrs, triton, scipy, requests, referencing, plotly, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numba, Jinja2, contourpy, scikit-learn, nvidia-cusolver-cu12, matplotlib, jsonschema-specifications, huggingface-hub, torch, tokenizers, seaborn, pynndescent, jsonschema, hdbscan, umap-learn, transformers, torchvision, torchaudio, nbformat, sentence-transformers, bertopic
# Successfully installed Cython-0.29.37 Jinja2-3.1.4 MarkupSafe-2.1.5 PyYAML-6.0.1 attrs-23.2.0 bertopic-0.16.2 certifi-2024.7.4 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 fastjsonschema-2.20.0 filelock-3.15.4 fonttools-4.53.1 fsspec-2024.6.1 hdbscan-0.8.37 huggingface-hub-0.24.0 idna-3.7 importlib_resources-6.4.0 joblib-1.4.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.5 llvmlite-0.43.0 matplotlib-3.9.1 mpmath-1.3.0 nbformat-5.10.4 networkx-3.2.1 numba-0.60.0 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 pandas-2.2.2 pillow-10.4.0 plotly-5.22.0 pynndescent-0.5.13 pyparsing-3.1.2 pytz-2024.1 referencing-0.35.1 regex-2024.5.15 requests-2.32.3 rpds-py-0.19.0 safetensors-0.4.3 scikit-learn-1.5.1 scipy-1.13.1 seaborn-0.13.2 sentence-transformers-3.0.1 sympy-1.13.1 tenacity-8.5.0 threadpoolctl-3.5.0 tokenizers-0.19.1 torch-2.3.1 torchaudio-2.3.1 torchvision-0.18.1 tqdm-4.66.4 transformers-4.42.4 triton-2.3.1 tzdata-2024.1 umap-learn-0.5.6 urllib3-2.2.2

# %% [markdown]
# ## Cargar las librerías necesarias

# %% [markdown]
# ## 2. Exploración de datos <a id="second"></a>

# %%
### Se inicia cargando el archivo csv
csv_file_path = 'data_original/Tweets/davivienda_tweets.csv'
### Se carga el archivo csv en un dataframe
df = pd.read_csv(csv_file_path)

# %% [markdown]
# ## 3. nn <a id="third"></a>

# %%
# Continuado con el desarrollo se procede a realizar el análisis de tópicos
# Se crea un modelo UMAP, esto con el fin de tener consistencia en los resultados
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=5)
# Se crea el modelo BERTopic
# Se establece el parámetro embedding_model='paraphrase-MiniLM-L3-v2' para utilizar el modelo de lenguaje MiniLM.
# Se establece el parámetro min_topic_size para que se creen tópicos con un n tweets.
# Se establece el parámetro language="multilingual" para que el modelo sea capaz de procesar texto en varios idiomas.
# Se establece el parámetro nr_topics='auto' para que el modelo determine automáticamente el número de tópicos y evitar tópicos comunes
model = BERTopic(verbose=True, embedding_model='paraphrase-MiniLM-L3-v2', min_topic_size= 3, language="multilingual", nr_topics='auto', umap_model=umap_model)


# Se ajusta el modelo a los tweets
# Se extraen los tópicos y las palabras clave de los tópicos
headline_topics, _ = model.fit_transform(df.Embedded_text)
# Out:
# 2024-07-20 12:53:57,661 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 57/57 [00:00<00:00, 113.70it/s]
# 2024-07-20 12:53:59,288 - BERTopic - Embedding - Completed ✓
# 2024-07-20 12:53:59,288 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-07-20 12:54:08,198 - BERTopic - Dimensionality - Completed ✓
# 2024-07-20 12:54:08,199 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-07-20 12:54:08,243 - BERTopic - Cluster - Completed ✓
# 2024-07-20 12:54:08,243 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-07-20 12:54:08,327 - BERTopic - Representation - Completed ✓
# 2024-07-20 12:54:08,328 - BERTopic - Topic reduction - Reducing number of topics
# 2024-07-20 12:54:08,384 - BERTopic - Topic reduction - Reduced number of topics from 119 to 40

# %% [markdown]
# ## 4. nn <a id="fourth"></a>

# %% [markdown]
# ## 5. Análisis de resultados <a id="fifth"></a>

# %%
# Contar la frecuencia de cada valor único en la columna 'Sentimiento' del DataFrame df
sentiment_counts = df['Sentimiento'].value_counts()
# Imprimir el recuento de frecuencias para cada categoría de sentimiento
print(sentiment_counts)
# Out:
# Sentimiento
# NEG    859
# NEU    835
# POS    117
# Name: count, dtype: int64
